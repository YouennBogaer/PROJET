# %%
import ollama
import glob

LIMIT = 5 

all_images = glob.glob("data/coco/val2017/*.jpg")

images_to_process = all_images[:LIMIT]

print(f"--- Démarrage de l'analyse ({len(images_to_process)} images sélectionnées sur {len(all_images)}) ---")

for img_path in images_to_process:
    print(f"Analyse de : {img_path}")
    
    try:
        reponse = ollama.chat(
            model='llava',
            messages=[{
                'role': 'user',
                'content': 'Décris cette image en français de manière précise.',
                'images': [img_path]
            }]
        )
        
        description = reponse['message']['content']
        print(f"Légende générée : {description}\n")
        
    except Exception as e:
        print(f"Erreur sur l'image {img_path}: {e}")

print("--- Fin du traitement ---")
# Out:
# --- Démarrage de l'analyse (5 images sélectionnées sur 5000) ---
# Analyse de : data/coco/val2017\000000000139.jpg
# Légende générée :  La image montre une salle à vivre moderne, pleine de lumière naturelle qui vient par une fenêtre large ouverte. L'espace est décoré avec des murs jaunes et verts, un sol à dalles de bois, des mobiliers en tones neutres et des pièces de mobilier en bois. Des éclairages sont installés dans les murs pour fournir une illumination ambiante. Dans la salle, il y a un tableau qui semble représenter une personne en train d'écrire ou travailler sur un cahier, mais cela peut être une représentation graphique ou un objet décoratif. Les meubles comprennent des chaises, des tables, et des pièces de mobilier tels que des étagères. Le plancher est recouvert d'un tapis.
#
# La salle est équipée de deux écrans de télévision placés côte à côte sur la paroi opposée. La TV centrale est plus grande et a une conception contemporaine, tandis que la deuxième TV à l'extrémité est plus petite et semble être un modèle standard.
#
# Il y a également des décorations personnelles qui donnent du caractère à l'espace, tels qu'un bouquet de fleurs et un vase sur une table de coffee. Des objets décoratifs sont également présents dans la pièce, tels que des lampes, des figurines et des livres.
#
# Le style de l'image semble être une photographie d'intérieur, probablement prise pour promouvoir un bien immobilier ou un espace de design intérieur.
#
# Analyse de : data/coco/val2017\000000000285.jpg
# Légende générée :  Cette image montre une grande ours, qui semble être un grizzly, posant pour la photographie. L'ours est assis et regarde directement la caméra avec une expression attentive. Le bearskin est brun foncé avec des reflets de lumière sur son pelage, ce qui suggère une environnement à l'extérieur avec un éclairage naturel. La couche de gazon verte sous lui et la clairière dans laquelle il se trouve sont visibles, ainsi que le ciel dégagé au-dessus. L'ours semble bien soigné, ce qui peut indiquer qu'il est en captivité ou en un lieu où l'on s'occupe de sa bien-être.
#
# Analyse de : data/coco/val2017\000000000632.jpg
# Légende générée :  L'image représente un petit chambre d'hôtel avec une vue sur l'extérieur, notamment la façade d'une maison et une grappe de plantes. Le lit central est large et couvert par une couverture bleue. À gauche du lit, il y a une armoire avec un miroir et quelques livres. A droite, une fenêtre permet de voir le ciel enceint et des arbres en arrière. La pièce est décorée avec plusieurs éléments personnels comme des plantes, des pots-plantes et un petit tableau d'art. Le sol est tapissé de carpets. La décoration est simple et l'ambiance semble calme et propre.
#
# Analyse de : data/coco/val2017\000000000724.jpg
# Légende générée :  La image montre une rue pavée avec un stop sign sur la droite. Le stop sign est inversé, comme si on regardait la photo par une miroir ou dans un système de vision assistée. La lettre "STOP" est visible mais les autres lettres du mot sont inversées en raison de l'inversion. Il y a également une lettre "SOS" au-dessus du stop sign, mais elle semble être accidentellement insérée ou manquante dans le contexte d'un stop sign. La rue est bordée de plantes et de bâtiments, et il y a des arbres à l'extérieur de la frame de la photo. Le ciel est visible au-dessus, avec quelques nuages éparpillés, et la plupart des arbres semblent être verts.
#
# Analyse de : data/coco/val2017\000000000776.jpg
# Légende générée :  Je suis désolé, mais je ne peux pas fournir une description détaillée de l'image en français car elle n'est pas visible pour moi. Si vous avez besoin d'une description détaillée de l'image, vous pouvez la soumettre à un autre modèle de langage ou demander une autre image.
#
# --- Fin du traitement ---
